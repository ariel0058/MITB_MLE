# %%
import pyspark

spark = (
    pyspark.sql.SparkSession.builder
    .appName("lab2-check")
    .master("local[*]")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("ERROR")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/09/16 08:23:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df_gold = spark.read.parquet(
    "datamart/gold/label_store/gold_label_store_2025_01_01.parquet"
)

df_gold.show()
df_gold.printSchema()
# Out:
# +--------------------+-----------+-----+----------+-------------+
# |             loan_id|Customer_ID|label| label_def|snapshot_date|
# +--------------------+-----------+-----+----------+-------------+
# |CUS_0x1108_2024_0...| CUS_0x1108|    1|30dpd_6mob|   2025-01-01|
# |CUS_0x13b5_2024_0...| CUS_0x13b5|    0|30dpd_6mob|   2025-01-01|
# |CUS_0x13b8_2024_0...| CUS_0x13b8|    0|30dpd_6mob|   2025-01-01|
# |CUS_0x144f_2024_0...| CUS_0x144f|    1|30dpd_6mob|   2025-01-01|
# |CUS_0x14ec_2024_0...| CUS_0x14ec|    1|30dpd_6mob|   2025-01-01|
# |CUS_0x1595_2024_0...| CUS_0x1595|    0|30dpd_6mob|   2025-01-01|
# |CUS_0x15ec_2024_0...| CUS_0x15ec|    0|30dpd_6mob|   2025-01-01|
# |CUS_0x16fd_2024_0...| CUS_0x16fd|    1|30dpd_6mob|   2025-01-01|
# |CUS_0x183d_2024_0...| CUS_0x183d|    1|30dpd_6mob|   2025-01-01|
# |CUS_0x183e_2024_0...| CUS_0x183e|    0|30dpd_6mob|   2025-01-01|
# |CUS_0x1a56_2024_0...| CUS_0x1a56|    0|30dpd_6mob|   2025-01-01|
# ...

# %%
df_gold.groupBy("label").count().show()
# Out:
# +-----+-----+
# |label|count|
# +-----+-----+
# |    1|  155|
# |    0|  350|
# +-----+-----+
